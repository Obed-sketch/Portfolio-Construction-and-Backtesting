# %% [markdown]
# # Demo Quantitative Stock Selection Model: Analyst Forecast Dispersion

# %% [markdown]
# Vamos

# %% [markdown]
# The difficulty in generating this signal resides in merging data from two sources, the analyst forecasts and the prices. We will use **merge** function from pandas but, to do that, we need to generate a unique key for each row in both dataframes.

# %% [markdown]
# ## Merge Two Data Frames by Keys

# %%
import pandas as pd
import numpy as np
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'],
                    'value1': [1, 2, 3, 5]})
df2 = pd.DataFrame({'key': ['E', 'D', 'C', 'B'],
                    'value2': [5, 6, 7, 8]})
display(df1)
display(df2)
# Out:
#   key  value1
# 0   A       1
# 1   B       2
# 2   C       3
# 3   D       5
#   key  value2
# 0   E       5
# 1   D       6
# 2   C       7
# 3   B       8

# %% [markdown]
# Merge the two data frames on column "key". Use intersection of keys from both data frames. Preserve the order of keys from the left frame.

# %%
df3=pd.merge(df1,df2,on="key",how="inner")
df3
# Out:
#   key  value1  value2
# 0   B       2       8
# 1   C       3       7
# 2   D       5       6

# %% [markdown]
# Merge the two data frames on column "key". Use all keys from the left frame. Preserve the order of keys from the left frame.

# %%
#NaN will show up when the key is not available in the right frame
df3=pd.merge(df1,df2,on="key",how="left")
df3
# Out:
#   key  value1  value2
# 0   A       1     NaN
# 1   B       2     8.0
# 2   C       3     7.0
# 3   D       5     6.0

# %% [markdown]
# For more instruction about merge function, see https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html

# %% [markdown]
# ## Analyst Forecast Dispersion

# %% [markdown]
# $$
# \frac{\text{STD of Forecast }{t}}{\text{Price at }t}
# $$

# %% [markdown]
# ## Step 1: Generate Keys to Merge Data Frames

# %%
df1 = pd.read_csv('classdata/IBES.csv')

# %%
#We only select the columns we need
df1=df1[["CUSIP","STATPERS","NUMEST","MEANEST","STDEV"]]
df1.head()
# Out:
#       CUSIP  STATPERS  NUMEST  MEANEST  STDEV
# 0  87482X10  20140417       4     0.52   0.03
# 1  87482X10  20140515       4     0.56   0.04
# 2  87482X10  20140619       4     0.56   0.04
# 3  87482X10  20140717       3     0.56   0.05
# 4  87482X10  20140814       5     1.18   0.06

# %% [markdown]
# Remove the records with no more than two analyst forecasts.

# %%
df1=df1[df1.NUMEST>2]

# %% [markdown]
# We generate the unique key for each row in df1 as "CUSIP"+"STATPERS", which represents the stock and the date from which this row is generated.

# %%
df1=df1[["CUSIP","STATPERS","STDEV"]]
df1["key"]=df1["CUSIP"]+df1["STATPERS"].astype(str)
df1.head()
# Out:
#       CUSIP  STATPERS  STDEV               key
# 0  87482X10  20140417   0.03  87482X1020140417
# 1  87482X10  20140515   0.04  87482X1020140515
# 2  87482X10  20140619   0.04  87482X1020140619
# 3  87482X10  20140717   0.05  87482X1020140717
# 4  87482X10  20140814   0.06  87482X1020140814

# %% [markdown]
# We then load the data file that contains the last closing price available to IBES before the statistics (STDEV) were calculated.

# %%
df2 = pd.read_csv('classdata/ActualPrice.csv')
df2 = df2[["CUSIP","STATPERS","PRICE"]]
df2.head()
# Out:
#       CUSIP  STATPERS  PRICE
# 0  87482X10  20140417  13.75
# 1  87482X10  20140515  13.30
# 2  87482X10  20140619  14.40
# 3  87482X10  20140717  14.11
# 4  87482X10  20140814  13.76

# %% [markdown]
# Remove the records that have zero in prices.

# %%
df2=df2[df2.PRICE>0]

# %% [markdown]
# We generate the unique key for each row in df2 similarly.

# %%
df2["key"]=df2["CUSIP"]+df2["STATPERS"].astype(str)
df2=df2[["key","PRICE"]]
df2.head()
# Out:
#                 key  PRICE
# 0  87482X1020140417  13.75
# 1  87482X1020140515  13.30
# 2  87482X1020140619  14.40
# 3  87482X1020140717  14.11
# 4  87482X1020140814  13.76

# %% [markdown]
# Merge the two data frames (df1 and df2) on column "key". Use intersection of keys from both data frames. Preserve the order of the left keys.

# %%
df3=pd.merge(df1,df2,on="key",how="inner")
df3.head()
# Out:
#       CUSIP  STATPERS  STDEV               key  PRICE
# 0  87482X10  20140417   0.03  87482X1020140417  13.75
# 1  87482X10  20140515   0.04  87482X1020140515  13.30
# 2  87482X10  20140619   0.04  87482X1020140619  14.40
# 3  87482X10  20140717   0.05  87482X1020140717  14.11
# 4  87482X10  20140814   0.06  87482X1020140814  13.76

# %% [markdown]
# ## Step 2: Generate Signals and Available Quarters

# %% [markdown]
# Simply generate the signal in a new column.

# %%
df3["Signal"]=df3["STDEV"]/df3["PRICE"]
df3.head()
# Out:
#       CUSIP  STATPERS  STDEV               key  PRICE    Signal
# 0  87482X10  20140417   0.03  87482X1020140417  13.75  0.002182
# 1  87482X10  20140515   0.04  87482X1020140515  13.30  0.003008
# 2  87482X10  20140619   0.04  87482X1020140619  14.40  0.002778
# 3  87482X10  20140717   0.05  87482X1020140717  14.11  0.003544
# 4  87482X10  20140814   0.06  87482X1020140814  13.76  0.004360

# %%
#These libraries are loaded to move each date six months forwards (to the end of the returned month)
from dateutil.relativedelta import relativedelta

# %% [markdown]
# Generate **yyyymm** as $100\times year + 3\times quarter$ using list comprehension.

# %%
df3['STATPERS']=pd.to_datetime(df3['STATPERS'],format="%Y%m%d")
df3["year"]=[s.year for s in df3["STATPERS"]]
df3["quarter"]=[s.quarter for s in df3["STATPERS"]]
df3["Date"]=df3["year"]*100+df3["quarter"]*3
df3.head()
# Out:
#       CUSIP   STATPERS  STDEV               key  PRICE    Signal  year  \
# 0  87482X10 2014-04-17   0.03  87482X1020140417  13.75  0.002182  2014
# 1  87482X10 2014-05-15   0.04  87482X1020140515  13.30  0.003008  2014
# 2  87482X10 2014-06-19   0.04  87482X1020140619  14.40  0.002778  2014
# 3  87482X10 2014-07-17   0.05  87482X1020140717  14.11  0.003544  2014
# 4  87482X10 2014-08-14   0.06  87482X1020140814  13.76  0.004360  2014
#
#    quarter    Date
# 0        2  201406
# 1        2  201406
# 2        2  201406
# 3        3  201409
# 4        3  201409

# %% [markdown]
# Remove nan in df3 and sort df3.

# %%
df3.dropna(how='any',axis=0, inplace=True)
df3.sort_values(by=['CUSIP', 'Date'],inplace=True)
df3.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Step 3: Generate Summary Statistics

# %% [markdown]
# For signals constructed using IBES data on analyst forecasts, the data are available at monthly frequency. We must only keep the signal from the last month of a quarter. For example, the standard deviation of analyst forecast is available in Jan,
# Feb, and Mar of 2012. To construct the signal of analyst forecast dispersion for 201203, you only need the standard deviation measured in March 2012.

# %%
df3.groupby(["CUSIP"]).get_group("87482X10")
# Out:
#            CUSIP   STATPERS  STDEV               key  PRICE    Signal  year  \
# 598096  87482X10 2014-04-17   0.03  87482X1020140417  13.75  0.002182  2014
# 598097  87482X10 2014-05-15   0.04  87482X1020140515  13.30  0.003008  2014
# 598098  87482X10 2014-06-19   0.04  87482X1020140619  14.40  0.002778  2014
# 598099  87482X10 2014-07-17   0.05  87482X1020140717  14.11  0.003544  2014
# 598100  87482X10 2014-08-14   0.06  87482X1020140814  13.76  0.004360  2014
# 598101  87482X10 2014-09-18   0.06  87482X1020140918  14.76  0.004065  2014
# 598102  87482X10 2014-10-16   0.06  87482X1020141016  13.61  0.004409  2014
# 598103  87482X10 2014-11-20   0.03  87482X1020141120  13.95  0.002151  2014
# 598104  87482X10 2014-12-18   0.03  87482X1020141218  14.17  0.002117  2014
# 598105  87482X10 2015-01-15   0.03  87482X1020150115  13.17  0.002278  2015
# 598106  87482X10 2015-02-19   0.02  87482X1020150219  13.70  0.001460  2015
# 598107  87482X10 2015-03-19   0.02  87482X1020150319  14.93  0.001340  2015
# 598108  87482X10 2015-04-16   0.03  87482X1020150416  16.31  0.001839  2015
# 598109  87482X10 2015-05-14   0.05  87482X1020150514  15.76  0.003173  2015
# 598110  87482X10 2015-06-18   0.05  87482X1020150618  16.66  0.003001  2015
# 598111  87482X10 2015-07-16   0.03  87482X1020150716  17.94  0.001672  2015
# 598112  87482X10 2015-08-20   0.02  87482X1020150820  16.25  0.001231  2015
# 598113  87482X10 2015-09-17   0.03  87482X1020150917  16.38  0.001832  2015
# 598114  87482X10 2015-10-15   0.03  87482X1020151015  16.05  0.001869  2015
# 598115  87482X10 2015-11-19   0.01  87482X1020151119  18.00  0.000556  2015
# 598116  87482X10 2015-12-17   0.01  87482X1020151217  17.66  0.000566  2015
# 598117  87482X10 2016-01-14   0.10  87482X1020160114  16.64  0.006010  2016
# 598118  87482X10 2016-02-18   0.03  87482X1020160218  16.36  0.001834  2016
# 598119  87482X10 2016-03-17   0.04  87482X1020160317  17.31  0.002311  2016
# 598120  87482X10 2016-04-14   0.04  87482X1020160414  18.53  0.002159  2016
#
#         quarter    Date
# 598096        2  201406
# 598097        2  201406
# 598098        2  201406
# 598099        3  201409
# 598100        3  201409
# 598101        3  201409
# 598102        4  201412
# 598103        4  201412
# 598104        4  201412
# 598105        1  201503
# 598106        1  201503
# 598107        1  201503
# 598108        2  201506
# 598109        2  201506
# 598110        2  201506
# 598111        3  201509
# 598112        3  201509
# 598113        3  201509
# 598114        4  201512
# 598115        4  201512
# 598116        4  201512
# 598117        1  201603
# 598118        1  201603
# 598119        1  201603
# 598120        2  201606

# %% [markdown]
# We use **groupby** to group the rows with the same "CUSIP" and "Date". Then we use **.tail(1)** to only keep the last row, which is the latest month in each quarter (the one we are supposed to use).

# %%
df3.groupby(["CUSIP","Date"]).get_group(("87482X10",201412))
# Out:
#            CUSIP   STATPERS  STDEV               key  PRICE    Signal  year  \
# 598102  87482X10 2014-10-16   0.06  87482X1020141016  13.61  0.004409  2014
# 598103  87482X10 2014-11-20   0.03  87482X1020141120  13.95  0.002151  2014
# 598104  87482X10 2014-12-18   0.03  87482X1020141218  14.17  0.002117  2014
#
#         quarter    Date
# 598102        4  201412
# 598103        4  201412
# 598104        4  201412

# %%
df3.groupby(["CUSIP","Date"]).get_group(("87482X10",201412)).tail(1)
# Out:
#            CUSIP   STATPERS  STDEV               key  PRICE    Signal  year  \
# 598104  87482X10 2014-12-18   0.03  87482X1020141218  14.17  0.002117  2014
#
#         quarter    Date
# 598104        4  201412

# %% [markdown]
# By removing **.get_group(("87482X10",201412))** in the code above, we can remove duplicated Dates in all groups.

# %%
df3=df3.groupby(["CUSIP","Date"]).tail(1)
df3.reset_index(drop=True, inplace=True)

# %% [markdown]
# Let's check if this works.

# %%
df3.groupby(["CUSIP"]).get_group("87482X10")
# Out:
#            CUSIP   STATPERS  STDEV               key  PRICE    Signal  year  \
# 211237  87482X10 2014-06-19   0.04  87482X1020140619  14.40  0.002778  2014
# 211238  87482X10 2014-09-18   0.06  87482X1020140918  14.76  0.004065  2014
# 211239  87482X10 2014-12-18   0.03  87482X1020141218  14.17  0.002117  2014
# 211240  87482X10 2015-03-19   0.02  87482X1020150319  14.93  0.001340  2015
# 211241  87482X10 2015-06-18   0.05  87482X1020150618  16.66  0.003001  2015
# 211242  87482X10 2015-09-17   0.03  87482X1020150917  16.38  0.001832  2015
# 211243  87482X10 2015-12-17   0.01  87482X1020151217  17.66  0.000566  2015
# 211244  87482X10 2016-03-17   0.04  87482X1020160317  17.31  0.002311  2016
# 211245  87482X10 2016-04-14   0.04  87482X1020160414  18.53  0.002159  2016
#
#         quarter    Date
# 211237        2  201406
# 211238        3  201409
# 211239        4  201412
# 211240        1  201503
# 211241        2  201506
# 211242        3  201509
# 211243        4  201512
# 211244        1  201603
# 211245        2  201606

# %% [markdown]
# ## Step 4: Map CUSIP to PERMNO

# %% [markdown]
# If we want to obtain the PERMNO corresponding to each stock, we can read "cusip.csv" where a mapping between CUSIP and PERMNO is provided.

# %%
df4=pd.read_csv("classdata/cusip.csv")
df4["PERMNO"]=df4["PERMNO"].astype(str)
df4.head()
# Out:
#   PERMNO    NCUSIP
# 0  10000  68391610
# 1  10001  29269V10
# 2  10001  29274A10
# 3  10001  29274A20
# 4  10001  36720410

# %% [markdown]
# To do so, we just need to create a dictionary that maps NCUSIP to PERMNO.

# %%
dictionary=dict(zip(df4.NCUSIP,df4.PERMNO))

# %%
df3["PERMNO"]=df3.CUSIP.map(dictionary)
df3[["PERMNO","CUSIP","Date","Signal"]].head()
# Out:
#   PERMNO     CUSIP    Date    Signal
# 0    NaN  00000000  201712  0.007539
# 1    NaN  00000000  201803  0.000558
# 2    NaN  00000117  200403  0.001815
# 3    NaN  00000117  200406  0.001808
# 4    NaN  00001216  201403  0.001451

# %%
df3.dropna(how='any',axis=0, inplace=True)
df3.reset_index(drop=True,inplace=True)
df3[["PERMNO","CUSIP","STATPERS","Date","Signal"]].head()
# Out:
#   PERMNO     CUSIP   STATPERS    Date    Signal
# 0  14945  00030710 2014-12-18  201412  0.001345
# 1  14945  00030710 2015-02-19  201503  0.001358
# 2  14945  00030710 2015-09-17  201509  0.001672
# 3  14945  00030710 2015-12-17  201512  0.000887
# 4  14945  00030710 2016-03-17  201603  0.001766

# %% [markdown]
# ## Step 5: Generate Summary Statistics

# %%
df3[df3.quarter==4].groupby("Date")["Signal"].describe(percentiles=[0.1,0.9])
# Out:
#          count      mean         std  min       10%       50%       90%  \
# Date
# 200012  3418.0  0.032777    0.493325  0.0  0.000307  0.002032  0.021728
# 200112  2974.0  0.147527    2.902213  0.0  0.000321  0.001767  0.022554
# 200212  2724.0  0.015942    0.146234  0.0  0.000339  0.001691  0.016098
# 200312  2759.0  0.004325    0.030218  0.0  0.000285  0.001198  0.007515
# 200412  2958.0  0.004370    0.038976  0.0  0.000283  0.001182  0.006927
# 200512  3120.0  0.011268    0.251083  0.0  0.000313  0.001435  0.009190
# 200612  3241.0  0.004757    0.018384  0.0  0.000348  0.001467  0.009124
# 200712  3254.0  0.008877    0.063818  0.0  0.000388  0.001846  0.013768
# 200812  2976.0  0.039510    0.333627  0.0  0.000773  0.004815  0.042463
# 200912  2779.0  0.012195    0.109816  0.0  0.000521  0.002331  0.014976
# 201012  2946.0  0.012816    0.263559  0.0  0.000470  0.002018  0.013293
# 201112  2977.0  0.059994    1.680068  0.0  0.000518  0.002566  0.020408
# 201212  3052.0  0.014131    0.132629  0.0  0.000423  0.002139  0.017326
# 201312  3074.0  0.007070    0.035211  0.0  0.000316  0.001522  0.011862
# 201412  3317.0  0.008449    0.037113  0.0  0.000314  0.001675  0.014338
# 201512  3285.0  0.019692    0.162542  0.0  0.000337  0.001910  0.020811
# 201612  3142.0  0.014505    0.234865  0.0  0.000288  0.001496  0.017199
# 201712  3081.0  0.017549    0.285466  0.0  0.000265  0.001445  0.014807
# 201812  3148.0  2.196976  122.015262  0.0  0.000310  0.002039  0.023682
# 201912  3180.0  0.023344    0.208929  0.0  0.000268  0.001784  0.026254
#
#                 max
# Date
# 200012    19.500000
# 200112   139.000000
# 200212     3.428571
# 200312     1.402367
# 200412     1.966346
# 200512    13.000000
# 200612     0.709497
# 200712     2.862500
# 200812    14.000000
# 200912     4.526882
# 201012    13.600000
# 201112    68.563098
# 201212     4.750000
# 201312     1.080114
# 201412     0.875000
# 201512     4.840000
# 201612    12.800000
# 201712    12.500000
# 201812  6845.917893
# 201912     7.333333

# %% [markdown]
# Save the columns we want to a csv file.

# %%
df3[["PERMNO","STATPERS","Date","Signal"]].to_csv("Signal2.csv",index=False)
